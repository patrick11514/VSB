# %%
0.10 * 0.10
# Out:
# [1] 0.01

# %%
1 - 0.10 - 0.25 - 0.30 - 0.15
0.10 + 0.25 + 0.30 + 0.2
# Out:
# [1] 0.2
# [1] 0.85

# %%
P_V2 <- 1 - (0.10 + 0.25 + 0.30)
P_V2
# Out:
# [1] 0.35

# %%
(1 - (0.10 + 0.25 + 0.30 + 0.20)) / (P_V2)
# Out:
# [1] 0.4285714

# %%
E_X <- 0 * 0.10 + 1 * 0.25 + 2 * 0.30 + 3 * 0.20 + 4 * 0.15
E_X
# Out:
# [1] 2.05

# %%
E_X2 <- 0 * 0 * 0.10 + 1 * 1 * 0.25  + 2 * 2 * 0.30 + 3 * 3 * 0.20 + 4 * 4 * 0.15
D_X <- E_X2 - (E_X * E_X)
smer <- sqrt(D_X)
smer
# Out:
# [1] 1.203121

# %%
E_X <- 0 * 0.10 + 50 * 0.25 + 100 * 0.30 + 150 * 0.20 + 200 * 0.15
E_X
# Out:
# [1] 102.5

# %%
E_X2 <- 0 * 0 * 0.10 + 50 * 50 * 0.25  + 100 * 100 * 0.30 + 150 * 150 * 0.20 + 200 * 200 * 0.15
D_X <- E_X2 - (E_X * E_X)
smer <- sqrt(D_X)
smer
# Out:
# [1] 60.15605

# %%
lambda <- 1 / 11

# %%
1 - pexp(11, lambda)
# Out:
# [1] 0.3678794

# %%
(1 - pexp(13, lambda)) / (1 - pexp(8, lambda))
# Out:
# [1] 0.6347364

# %%
qexp(1 - 0.19, lambda)
# Out:
# [1] 18.26804

# %%
lambda_40 <- 40 * lambda
lambda_40
# Out:
# [1] 3.636364

# %%
1 / lambda_40
# Out:
# [1] 0.275

# %%
D_X <- 1 / (lambda_40 * lambda_40)
smer <- sqrt(D_X)
smer
# Out:
# [1] 0.275

# %%
pexp(14, lambda_40)
# Out:
# [1] 1
