# %%
0.1 * 0.95
0.1 * 0.05
0.9 * 0.02
0.9 * 0.98
0.095 + 0.018
0.095 / 0.113
# Out:
# [1] 0.095
# [1] 0.005
# [1] 0.018
# [1] 0.882
# [1] 0.113
# [1] 0.840708

# %%
EX <- 0 * 0.1 + 1 * 0.2 + 2 * 0.2 + 3 * 0.4 + 4 * 0.1
EX
# Out:
# [1] 2.2

# %%
EX2 <- 0 * 0 * 0.1 + 1 * 1 * 0.2 + 2 * 2 * 0.2 + 3 * 3 * 0.4 + 4 * 4 * 0.1
EX2
# Out:
# [1] 6.2

# %%
DX = EX2 - EX * EX
DX
# Out:
# [1] 1.36

# %%
sqrt(DX)
# Out:
# [1] 1.16619

# %%
EX_V <- 0 * 0.1 + 500 * 0.2 + 1000 * 0.2 + 1500 * 0.4 + 2000 * 0.1
EX_V
# Out:
# [1] 1100

# %%
EX2_V <- 0 * 0 * 0.1 + 500 * 500 * 0.2 + 1000 * 1000 * 0.2 + 1500 * 1500 * 0.4 + 2000 * 2000 * 0.1
DX_V <- EX2_V - EX_V * EX_V
sqrt(DX_V)
# Out:
# [1] 583.0952

# %%
E_X <- 0.2
lamda <- 1 / E_X
lamda
# Out:
# [1] 5

# %%
1 - pexp(0.5, lamda)
# Out:
# [1] 0.082085

# %%
qexp(0.05, lamda)
1 - qexp(0.95, lamda)
# Out:
# [1] 0.01025866
# [1] 0.4008535

# %%
1 - pbinom(109, 150, 0.8)
# Out:
# [1] 0.9813032

# %%
EX <- 0.8 * 150
EX

DX <- 150 * 0.8 * (1 - 0.8)
DX
# Out:
# [1] 120
# [1] 24
