# %%
import csv

import networkx as nx
import pandas as pd

hrany = open('Sit2.csv', "r") # Nazev souboru, pozor, bez prvniho radku (bez Source;Target;Weight)
#G = nx.parse_edgelist(hrany, delimiter=';',nodetype=str) # Nacitani NEvazene site
G = nx.read_weighted_edgelist(hrany, delimiter=';',nodetype=str) # Nacitani vazene site

G.add_node("X")
G.add_edge("X", "P")

nx.draw(G, with_labels = True)

# %%
import csv

import networkx as nx
import pandas as pd

hrany = open('Sit2.csv', "r") #Nazev souboru, pozor, bez prvniho radku (bez Source;Target;Weight)
#G = nx.parse_edgelist(hrany, delimiter=';',nodetype=str) # Nacitani nevazene site
G = nx.read_weighted_edgelist(hrany, delimiter=';',nodetype=str) # Nacitani vazene site

# 1. Pridejte novou hranu
# https://networkx.org/documentation/stable/reference/classes/graph.html

G.add_node("X")
G.add_edge("X", "P")


for edge in G.edges:
  source_node = edge[0]
  target_node = edge[1]

  print(source_node, target_node)

  # 2. Existuje vami vytvorena hrana?
# Out:
# M T
# M P
# M K
# M V
# M O
# M E
# M Vo
# T P
# T K
# T V
# T O
# T E
# T Vo
# P K
# P O
# P V
# P B
# P S
# P D
# P X
# K O
# K V
# K S
# K E
# K A
# K C
# K Vo
# O V
# O J
# O Mi
# O S
# V B
# V J
# V Mi
# V S
# J Mi
# S D
# E C
