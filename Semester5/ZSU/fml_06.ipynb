# %% [markdown]
# # Fundamentals of Machine Learning - Exercise 6
# * The goal of this excercise is to complete the hands-on experience task with similar task description as the project has.
#
# ![meme01](https://github.com/rasvob/VSB-FEI-Fundamentals-of-Machine-Learning-Exercises/blob/master/images/fml_06_meme_01.png?raw=true)

# %%
import numpy as np
import pandas as pd
import sklearn.preprocessing, sklearn.cluster, sklearn.metrics
from sklearn.cluster import AgglomerativeClustering, DBSCAN
from scipy.cluster.hierarchy import dendrogram
import scipy.spatial
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data description
#
# Data source: https://www.kaggle.com/datasets/subhajitnayak/country-data?resource=download&select=Country-data.csv
#
# |Attribute|Description|
# |:-------|:-------|
# |country | Name of the country |
# |child_mort | Death of children under 5 years of age per 1000 live births |
# |exports | Exports of goods and services. Given as %age of the Total GDP |
# |health | Total health spending as %age of Total GDP |
# |imports | Imports of goods and services. Given as %age of the Total GDP |
# |Income | Net income per person |
# |Inflation | The measurement of the annual growth rate of the Total GDP |
# |life_expec | The average number of years a new born child would live if the current mortality patterns are to rem... |
# |total_fer | The number of children that would be born to each woman if the current age-fertility rates remain th... |
# |gdpp | The GDP per capita. Calculated as the Total GDP divided by the total population. |

# %% [markdown]
# ## Load the data

# %%
df = pd.read_csv('https://github.com/rasvob/VSB-FEI-Fundamentals-of-Machine-Learning-Exercises/raw/master/datasets/country-data.csv')
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %%
df.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# ...

# %% [markdown]
# ## Check the numerical features first

# %%
df_only_numeric = df.select_dtypes(np.number)

# Create the subplots
n_rows, n_cols = df_only_numeric.shape
fig, axes = plt.subplots(nrows=1, ncols=n_cols, figsize=(40, 6))
for i, column in enumerate(df_only_numeric):
    sns.histplot(data=df_only_numeric, x=column, ax=axes[i]).set_title(column)

# %% [markdown]
# # 🔎 Is it wise to scale the data?
# * 🔎 Why do we want to preprocess the data?
# * What different options do we have?

# %% [markdown]
# # Data preprocessing

# %%
X = df_only_numeric.values

# %%
scaler = sklearn.preprocessing.MinMaxScaler()
X_min_max_scaled = scaler.fit_transform(X)
X_min_max_scaled
# Out:
# array([[0.42648491, 0.04948197, 0.35860783, ..., 0.47534517, 0.73659306,
#         0.00307343],
#        [0.06815969, 0.13953104, 0.29459291, ..., 0.87179487, 0.07886435,
#         0.03683341],
#        [0.12025316, 0.1915594 , 0.14667495, ..., 0.87573964, 0.27444795,
#         0.04036499],
#        ...,
#        [0.10077897, 0.35965101, 0.31261653, ..., 0.8086785 , 0.12618297,
#         0.01029885],
#        [0.26144109, 0.1495365 , 0.20944686, ..., 0.69822485, 0.55520505,
#         0.01029885],
#        [0.39191821, 0.18455558, 0.25357365, ..., 0.39250493, 0.670347  ,
#         0.01173057]])

# %%
df.select_dtypes(np.number).columns
# Out:
# Index(['child_mort', 'exports', 'health', 'imports', 'income', 'inflation',
#        'life_expec', 'total_fer', 'gdpp'],
#       dtype='object')

# %%
df_scaled = pd.DataFrame(X_min_max_scaled, columns=df_only_numeric.columns)

# %%
df_scaled
# Out:
#      child_mort   exports    health   imports    income  inflation  \
# 0      0.426485  0.049482  0.358608  0.257765  0.008047   0.126144
# 1      0.068160  0.139531  0.294593  0.279037  0.074933   0.080399
# 2      0.120253  0.191559  0.146675  0.180149  0.098809   0.187691
# 3      0.566699  0.311125  0.064636  0.246266  0.042535   0.245911
# 4      0.037488  0.227079  0.262275  0.338255  0.148652   0.052213
# ..          ...       ...       ...       ...       ...        ...
# 162    0.129503  0.232582  0.213797  0.302609  0.018820   0.063118
# 163    0.070594  0.142032  0.192666  0.100809  0.127750   0.463081
# 164    0.100779  0.359651  0.312617  0.460715  0.031200   0.150725
# 165    0.261441  0.149536  0.209447  0.197397  0.031120   0.257000
# 166    0.391918  0.184556  0.253574  0.177275  0.021473   0.168284
#
#      life_expec  total_fer      gdpp
# 0      0.475345   0.736593  0.003073
# 1      0.871795   0.078864  0.036833
# 2      0.875740   0.274448  0.040365
# ...

# %% [markdown]
# # ✅ Task (2p)
# ## Use k-means or agglomerative clustering algorithm to cluster the data
# - 🔎 How many clusters did you choose? Why?
#
# ## Perform an exploration analysis of the clustered data
# - 💡Write down your conlusions about differences/similarities about the feature characteristics according to the individial clusters
#
# ## 🎯 Write down a conlustion about clusters as a whole, i.e. try to characterize the data in them in a few sentences
# - Cluster 1 - ...
# - Cluster 2 - ...
# - ...
# - Cluster N - ...
#
# * **Describe the insight you got from the plots with a few sentences in a Markdown cell below the plot**
#   * ❌ Plot interpretation figured in real-time during task check is not allowed! ❌

# %% [markdown]
# INFO:
#
# k-means - siluette coeficient + sse - elbow method do grafu, pak se rozhodnout na optimální clustering
# agglo - dendogram
#  => clustering - vrátí labely, uložit do df a vizualizovat na původních datech !!!
#
#  Countplot - napsat jestli rovnoměrně rozdělené nebo ne, co převažuje/je výrazně větší - vybalancované/nevybalancované (boxplot, histogram, hue=cluter_id, violinplot) - 2-3 grafy a větičku, co jsme našli a pospat jednotlivé clustery
#
#  PROJEKT INFO:
#  - kategorické: count plot
#  - numerické: scatterplot/histogram, boxplot (pozor, numerické mohou být kategorickýma, takže ne pro 0,1 třeba)
#
#  Graf + popis, ne více grafů najednou + popis
#
#  - Kolerační matice - heatmap
#
#   Radši míň grafů, ale kvalitnější popis
#
#
#   Clustering:
#   - chybějící hodnoty - vyplnit (průměr) / drop
#   - vyčištění dat - kategorická data (label-ordinal/one-hot, ordinal nemopu na neseřazené data (jméno jídel)), numerické - min-max scaling, standart scaler, power transformer
#   - clustering algoritmy - kmeans

# %% [markdown]
# # 🚀 Let's get started!
#
# ![meme02](https://github.com/rasvob/VSB-FEI-Fundamentals-of-Machine-Learning-Exercises/blob/master/images/fml_06_meme_02.jpg?raw=true)

# %%
def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram
    # Credit to https://scikit-learn.org/stable/auto_examples/cluster/plot_agglomerative_dendrogram.html

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    plt.title('Hierarchical Clustering Dendrogram')
    dendrogram(linkage_matrix, **kwargs)
    plt.ylabel('distance')

# %%
clustering = AgglomerativeClustering(linkage='complete', distance_threshold=0, n_clusters=None)
clustering = clustering.fit(df_scaled)

plt.title('Hierarchical Clustering Dendrogram')
plot_dendrogram(clustering, labels=clustering.labels_, color_threshold=999)

# %% [markdown]
# Když se podíáváme na dendogram, nejlíp vypadají asi 3 clustery, něco mezi distance 1.5 - <1.75. Pojďme se ještě podívat na single linkage.

# %%
clustering = AgglomerativeClustering(linkage='single', distance_threshold=0, n_clusters=None)
clustering = clustering.fit(df_scaled)

plt.title('Hierarchical Clustering Dendrogram')
plot_dendrogram(clustering, labels=clustering.labels_, color_threshold=999)

# %% [markdown]
# U něho můžeme diět nejspíše 2 clustry s distance mezi 0.7 a 0.8. Pojďme si projít výsledky

# %%
clustering = AgglomerativeClustering(linkage='complete', distance_threshold=None, n_clusters=3)
clustering = clustering.fit(df_scaled)
pd.Series(clustering.labels_).value_counts()
# Out:
# 0    131
# 1     33
# 2      3
# Name: count, dtype: int64

# %%
clustering = AgglomerativeClustering(linkage='single', distance_threshold=None, n_clusters=2)
clustering = clustering.fit(df_scaled)
pd.Series(clustering.labels_).value_counts()
# Out:
# 0    166
# 1      1
# Name: count, dtype: int64

# %% [markdown]
# Nakonec si teda volím 3 clustery, v complete linkage, protože není úplně nejlepší mít dva clustery, kdy druhý má pouze 1 stát.

# %% [markdown]
# Pojďme prozkoumat data

# %%
clustering = AgglomerativeClustering(linkage='complete', distance_threshold=None, n_clusters=3)
clustering = clustering.fit(df_scaled)
pd.Series(clustering.labels_).value_counts()

df["cluster_id"] = clustering.labels_

# %%
for column in df.columns:
    if column == "cluster_id" or column == "country":
        continue
    sns.boxplot(data=df, x="cluster_id", y=column)    
    plt.show()

# %%
df[df["cluster_id"] == 2]
# Out:
#         country  child_mort  exports  health  imports  income  inflation  \
# 91   Luxembourg         2.8    175.0    7.77    142.0   91700      3.620
# 98        Malta         6.8    153.0    8.65    154.0   28300      3.830
# 133   Singapore         2.8    200.0    3.96    174.0   72100     -0.046
#
#      life_expec  total_fer    gdpp  cluster_id
# 91         81.3       1.63  105000           2
# 98         80.3       1.36   21100           2
# 133        82.7       1.15   46600           2

# %% [markdown]
# Když se podíváme, tak:
# 1. cluster má: malou úmrtnost, malý export, průměrné zdraví, malý import, menší příjmy, průměrná inflace, dobrá délka života, dobrá porodnost a průměrné GDP
# V tomto clutery je teda většina států, například státy Evropy: Česká Republika, Slovensko, Polsko, Francie etc...
#
# 2. cluster má: vysoká úmrtnost, malý export, průměrné zdraví, průměrný import, velmi nízké příjmy, průměrná inflace, velmi nízkou délku života, velmi vysoká porodnost a nízké GDP
# V tomto clusteru jsou tedy velmi chudé země, kde je špatné zdravotnictví, vysoká úmrtnost a nízké příjmy. Například státy Afriky.
#
# 3. Nízká úmrtnost, vysoký export, nadprůměrná délka života, vysoký import, vysoký příjem, mírně nižší inflace, vysoká délka života, nízká porodnost, velké GDP
# V tomto clusteru jsou státy, které jsou velmi založené na ekonomice, hlavně ve velkém importují/exportují, mezi ně patří: Luxembursko, Malta a Singapur
